# %%
print("Press 1 for currency Convesion\nPress 2 for Temperature Convesion\nPress 3 for Grading system\nPress 4 for Matrix inverse\nPress 5 for Quardratic")
x=int(input("\nEnter your Choice: "))
if x==1:
#program 01
 
    print("1.Dollar to Pkr\n2.Pkr to Dollar")
    x=int(input("\nEnter your choice: "))
    if x==1: 
        # currney convertion Dollar to pkr  
        doolar_price=279.65
        x=int(input("\nEnter the amount in Dollars: "))
        amount_in_rupees=((x)*(doolar_price))
        print("\nYour amount in rupees is: ", amount_in_rupees)
    elif x==2:
        # currney convertion Pkr to Dollar
        doolar_price=279.65
        x=int(input("\nEnter the amount in Rupees: "))
        amount_in_rupees=((x)/(doolar_price))
        print("\nYour amount in Dollar is: ", amount_in_rupees)
    else:
          print("Invalid entry")
elif x==2:
# program 02
    #Temperature Convertion Program
    print("Welcome to Temperature Conversion program\n")
    print("1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")

    x = input("\nEnter your choice: ")

    if x == '1':
        x = float(input("\nEnter the temperature in Celsius: "))
        if x < -273.15:  # Absolute zero, the lowest possible temperature
            print("\nWarning: Temperature value is below absolute zero!")
        else:
            y = ((9/5) * x) + 32
            print("\nTemperature in Fahrenheit is:", y)

    elif x == '2':
        x = float(input("\nEnter the temperature in Fahrenheit: "))
        if x < -459.67:  # Absolute zero in Fahrenheit scale
            print("\nWarning: Temperature value is below absolute zero!")
        else:
            y = (5/9) * (x - 32)
            print("\nTemperature in Celsius is:", y)
        
    else:
        print("\nInvalid Choice, Please Enter 1 or 2")
elif x==3:
#program 03          
##Grade programe
    x=int(input("Enter the value of a: "))
    y=int(input("Enter the value of b: "))
    z=int(input("Enter the value of c: "))
    x=(x+y+z)
    y=150
    z=(x/y)*100
    print("\nYour percentage is",z)
    if percentage>=90:
        print("\nYour grade is A")
    elif percentage>=80:
        print("\nYour grade is B")
    elif percentage>=70:
        print("\nYour grade is C")
    elif percentage>=60:
        print("\nYour grade is D")  
    else:
        print("\nYour grade is F and you are fail")
        
elif x==4:
#program 04          
#Matrix Inverse program
    print("\n    [a11    a12] \nA = \n    [a21    a22]")
    print("\nWrite matrix elements according to given position: ")
    x=float(input("\n""Enter the value of a11: "))
    y=float(input("Enter the value of a12: "))
    z=float(input("Enter the value of a21: "))
    xy=float(input("Enter the value of a22: "))
    print("\nYour Matrix is:")
    print("\n    [",x," ",y,"]","\nA =","\n    [",z," ",xy,"]")

    det=(x*xy)-(z*y)

    
    if det==0:
        print("\nInverse not exist:")
    else:
        print("\nInverse of the Matrix is:","\n\n      [",(1/det)*xy,"  ",(1/det)*(-y),"]","\nA^-1 =","\n      [",(1/det)*(-z),"  ",(1/det)*(x),"]")

elif x==5:
#program 05
    print("          __________")
    print("    -b ± √ b^2 - 4ac")
    print("𝓍 = ————————————————")
    print("          2a")
# Check real or imaginary nmber
    import math as m
    a=int(input("\nEnter the value of a: "))
    b=int(input("Enter the value of b: "))
    c=int(input("Enter the value of c: "))
    x= b**2 - 4*a*c
    if x>= 0:
        z = (-b + m.sqrt(x)) / (2*a)
        # print("\nYour first answer is:", z)
        print(" ")
        print("          __________")
        print("    -b + √ b^2 - 4ac")
        print("𝓍1 = ———————————————— =", z)
        print("          2a")
        print(" ")
        z = (-b - m.sqrt(x)) / (2*a)
        print("          __________")
        print("    -b - √ b^2 - 4ac")
        print("𝓍2 = ———————————————— =", z)
        print("          2a")
        # print("\nYour second answer is:", z)

    else:
        print("\nNo real solutions exist.The answer is an imaginary numbers")
else:
     print("Invalid entry, please choose correct option!")
# Out:
# Press 1 for currency Convesion
# Press 2 for Temperature Convesion
# Press 3 for Grading system
# Press 4 for Matrix inverse
# Press 5 for Quardratic
# Enter your Choice:  5
#           __________
#     -b ± √ b^2 - 4ac
# 𝓍 = ————————————————
#           2a
# Enter the value of a:  2
# Enter the value of b:  9
# Enter the value of c:  4
#
#           __________
#     -b + √ b^2 - 4ac
# 𝓍1 = ———————————————— = -0.5
#           2a
#
#           __________
#     -b - √ b^2 - 4ac
# 𝓍2 = ———————————————— = -4.0
#           2a
